# %%
% cd /Users/chang/Desktop/Global A.I./Master Database Project
# Out:
# /Users/chang/Desktop/Global A.I./Master Database Project

# %%
import numpy as np
import pandas as pd

# %%
import ClimateWatch_grabber
import Fred_grabber
# import ResourceWatch_grabber
# import WorldBank_grabber
# import tooll

# %% [markdown]
# # ClimateWatch Data
# ### Numerical Master Table

# %%
numerical_yearly_CW = ClimateWatch_grabber.handle_emission_data(ClimateWatch_grabber.get_emission())
# Out:
# processing page:1
# processing page:2
# processing page:3
# processing page:4
# processing page:5
# processing page:6
# processing page:7
# processing page:8
# processing page:9
# processing page:10
# processing page:11
# processing page:12
# processing page:13
# processing page:14
# processing page:15
# processing page:16
# processing page:17
# processing page:18
# processing page:19
# processing page:20
# processing page:21
# processing page:22
# processing page:23
# processing page:24
# processing page:25
# processing page:26
# processing page:27
# processing page:28
# processing page:29
# processing page:30
# processing page:31
# processing page:32
# processing page:33
# processing page:34
# processing page:35
# processing page:36
# processing page:37
# processing page:38
# processing page:39
# processing page:40
# processing page:41
# processing page:42
# processing page:43
# processing page:44
# processing page:45
# processing page:46
# processing page:47
# processing page:48
# ...

# %% [markdown]
# # Fred Data (OECD Countries)

# %%
numerical_Fred = Fred_grabber.get_Fred_Master()
# Out:
# no such series for Australia
# no such series for Canada
# no such series for Chile
# no such series for Greece
# no such series for Iceland
# no such series for Ireland
# no such series for Israel
# no such series for Japan
# no such series for Korea
# no such series for Mexico
# no such series for New Zealand
# no such series for Slovak Republic
# no such series for Turkey
# no such series for United States
# alternative series added for Australia
# alternative series added for Canada
# alternative series added for Chile
# alternative series added for Greece
# alternative series added for Iceland
# alternative series added for Ireland
# no alternative series found for Israel
# alternative series added for Japan
# alternative series added for Korea
# no alternative series found for Mexico
# alternative series added for New Zealand
# alternative series added for Slovak Republic
# alternative series added for Turkey
# alternative series added for United States
# ...

# %% [markdown]
# # Building Master table

# %%
# numerical_table_list = [numerical_yearly_CW, numerical_yearly_RW, numerical_yearly_Fred, numerical_yearly_WB]

# %%
# numerical_master = reduce(lambda x, y: pd.merge(x, y, on = ['country','year']), numerical_table_list)

# %%
numerical_yearly_CW.to_csv('yearly.csv',index = False)
numerical_Fred.to_csv('quarterly.csv',index = False)
