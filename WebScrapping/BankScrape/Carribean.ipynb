# %%
import re
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
import pandas as pd

# %%
my_url = 'https://www.caribank.org/our-work/projects-map/list-projects'
path=r'C:\Users\yzhhu\Desktop\G.A.I_summer\bank grabber\carribean'
uClient = uReq(my_url)
page_html = uClient.read()
uClient.close()

#parse HTML
page_soup = soup(page_html, "html.parser")

# %%
links = [a['href'] for a in page_soup.find_all('a', href=True)]

# %%
lst=[]
for i in links:
    if '/our-work/projects-map/' in i:
        lst.append(i)

# %%
lst[2:]
# Out:
# ['/our-work/projects-map/support-establishment-specialised-micro-and-small-business-financing-assessment-unit-within',
#  '/our-work/projects-map/essex-valley-irrigation-project',
#  '/our-work/projects-map/strengthening-food-safety-management-systems',
#  '/our-work/projects-map/energy-efficiency-measures-and-solar-photovoltaic-plant',
#  '/our-work/projects-map/road-and-bridge-rehabilitation-loubiere-bagatelle-road-and-road-network-and-road-safety-assessment',
#  '/our-work/projects-map/road-infrastructure-rehabilitation',
#  '/our-work/projects-map/education-quality-improvement-project',
#  '/our-work/projects-map/water-supply-expansion-and-sewerage-improvement-project',
#  '/our-work/projects-map/skills-development-and-employability-project',
#  '/our-work/projects-map/technical-assistance-geomatics-capacity-enhancement-disaster-risk-management',
#  '/our-work/projects-map/street-and-flood-light-retrofitting-project',
#  '/our-work/projects-map/power-project-electricity-system-upgrade-and-expansion',
#  '/our-work/projects-map/second-road-infrastructure-rehabilitation-project',
#  '/our-work/projects-map/street-light-retrofitting-project',
#  '/our-work/projects-map/climate-smart-agriculture-and-rural-enterprise-programme',
#  '/our-work/projects-map/rehabilitation-and-reconstruction-loan-hurricane-irma',
#  '/our-work/projects-map/costal-and-river-infrastructure-rehabilitation-preparation-feasibility-study-and-detailed-designs',
#  '/our-work/projects-map/rehabilitation-and-reconstruction-loan-hurricane-maria',
#  '/our-work/projects-map/hurricane-recovery-support-loan',
#  '/our-work/projects-map/port-modernisation-project-kingstown-st-vincent-and-grenadines',
#  '/our-work/projects-map/millennium-highway-and-west-coast-road-upgrading-project',
#  '/our-work/projects-map/montserrat-port-development-project',
#  '/our-work/projects-map/coastal-highway-upgrading-feasibility-study-and-preparation-detailed-designs',
#  '/our-work/projects-map/education-sector-support-project',
#  '/our-work/projects-map/seventh-power-project',
#  '/our-work/projects-map/emergency-support-loan-liat-1974-limited',
#  '/our-work/projects-map/emergency-support-loan-liat-1974-limited-1',
#  '/our-work/projects-map/rehabilitation-and-reconstruction-hurricane-irma',
#  '/our-work/projects-map/eighth-consolidated-line-credit',
#  '/our-work/projects-map/belize-social-investment-fund-iii',
#  '/our-work/projects-map/third-growth-and-resilience-building-policy-based-loan',
#  '/our-work/projects-map/energy-sector-policy-based-loan',
#  '/our-work/projects-map/power-project-suriname-electricity-system-upgrade-and-expansion',
#  '/our-work/projects-map/support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2013-2014-hurricane',
#  '/our-work/projects-map/education-all-project-phase-ii',
#  '/our-work/projects-map/support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2014-2015-hurricane',
#  '/our-work/projects-map/technical-assistance-sanitation-and-governance-training-programme',
#  '/our-work/projects-map/support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2015-2016-hurricane',
#  '/our-work/projects-map/technical-and-vocational-education-and-training-project-ii-republic-haiti',
#  '/our-work/projects-map/community-based-agriculture-and-rural-development',
#  '/our-work/projects-map/disaster-management-emergency-relief-grant-hurricane-matthew',
#  '/our-work/projects-map/support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2017-2018-hurricane',
#  '/our-work/projects-map/enhancement-technical-and-vocational-education-and-training-lower-secondary-school-level-suriname',
#  '/our-work/projects-map/economic-stability-and-resilience-building-policy-based-loan-british-virgin-islands',
#  '/our-work/projects-map/youth-resilience-and-inclusive-social-empowerment-rise-project',
#  '/our-work/projects-map/immediate-response-hurricane-earl',
#  '/our-work/projects-map/technical-and-vocational-education-and-training-development-revision-scope-additional-loan',
#  '/our-work/projects-map/anguilla-bank-resolution-bridge-bank-capitalisation',
#  '/our-work/projects-map/disaster-reduction-climate-change-adaptation',
#  '/our-work/projects-map/third-water-supply-project-water-area-1-network-upgrade',
#  '/our-work/projects-map/preparation-comprehensive-sport-development-initiative-new-faculty-sport-university-west-indies',
#  '/our-work/projects-map/establishment-caribbean-regional-technical-assistance-centre-continuation-support-contribution-phase',
#  '/our-work/projects-map/african-caribbean-pacific-european-union-caribbean-development-bank-natural-disaster-risk-management',
#  '/our-work/projects-map/building-individual-and-social-resilience-cope-impacts-natural-hazard-events-enhancing-capacity',
#  '/our-work/projects-map/rehabilitation-and-reconstruction-loan-hurricane-maria-dominica-electricity-services-limited',
#  '/our-work/projects-map/support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2016-2017-hurricane',
#  '/our-work/projects-map/building-capacity-disaster-risk-management-and-climate-resilience-project-ile-vache',
#  '/our-work/projects-map/quality-enhancement-public-education']

# %%
final_link=list(map(lambda x:'https://www.caribank.org'+x,lst[2:]))

# %%
final_link[:5]
# Out:
# ['https://www.caribank.org/our-work/projects-map/support-establishment-specialised-micro-and-small-business-financing-assessment-unit-within',
#  'https://www.caribank.org/our-work/projects-map/essex-valley-irrigation-project',
#  'https://www.caribank.org/our-work/projects-map/strengthening-food-safety-management-systems',
#  'https://www.caribank.org/our-work/projects-map/energy-efficiency-measures-and-solar-photovoltaic-plant',
#  'https://www.caribank.org/our-work/projects-map/road-and-bridge-rehabilitation-loubiere-bagatelle-road-and-road-network-and-road-safety-assessment']

# %%
#先做一个
link='https://www.caribank.org/our-work/projects-map/support-establishment-specialised-micro-and-small-business-financing-assessment-unit-within'
bluClient = uReq(link)
blupage_html = bluClient.read()
bluClient.close()
blupage_soup = soup(blupage_html, 'html')

# %%
#find overview 
a=blupage_soup.find_all('div',{'class':['field--wrap field--node field--node--full field--node--body']})
b=str(a).replace('<p>','</p>')
description=b.split('</p>')[1]
# Out:
# 'This Project is expected to contribute to increased access to business loan and saving products and services for female and male-owned micro and small enterprises (MSEs). It will support the establishment of a professionalised MSE business financing assessment unit within Le Levier, a network of savings and credit cooperatives in Haiti.'

# %%
#find date
#blupage_soup.find_all('div',{'class':['field--label']})
c=blupage_soup.find_all('div',{'class':['field--wrap field--node--field-date-of-approval field-display--above']})
d=str(c).replace('<div>','</div>')
date=d.split('</div>')[2]
# Out:
# 'May, 2016'

# %%
# find country
#need try_catch 
e=blupage_soup.find_all('div',{'class':['node--contry-tag']})
f=str(e).split('hreflang="en">')[1]
country=f.split('</a>')[0]
# Out:
# 'Haiti'

# %%
#find budget
g=blupage_soup.find_all('div',{'class':['field--wrap field--node--field-cdb-approved-budget field-display--above']})
h=str(g).replace('<div>','</div>')
approved_total=h.split('</div>')[2]

# %%
# find status 
gg=blupage_soup.find_all('div',{'class':['field--wrapp']})
status=str(gg).split('</span>')[1].split('</div>')[0]
# Out:
# 'Active'

# %%
table=pd.DataFrame([[description,date,country,status]],columns=['description','date','country','status'])
table
# Out:
#                                          description       date country  \
# 0  This Project is expected to contribute to incr...  May, 2016   Haiti
#
#    status
# 0  Active

# %%
#再做所有
big_table=pd.DataFrame()
for i in final_link:
    bluClient = uReq(i)
    blupage_html = bluClient.read()
    bluClient.close()
    blupage_soup = soup(blupage_html, 'html')
    #get name
    name=i.split('/')[-1]
    #find overview 
    a=blupage_soup.find_all('div',{'class':['field--wrap field--node field--node--full field--node--body']})
    b=str(a).replace('<p>','</p>')
    description=b.split('</p>')[1]
    #find date
    c=blupage_soup.find_all('div',{'class':['field--wrap field--node--field-date-of-approval field-display--above']})
    d=str(c).replace('<div>','</div>')
    date=d.split('</div>')[2]
    # find country
    #need try_catch 
    e=blupage_soup.find_all('div',{'class':['node--contry-tag']})
    f=str(e).split('hreflang="en">')[1]
    country=f.split('</a>')[0]
    #find budget
    g=blupage_soup.find_all('div',{'class':['field--wrap field--node--field-cdb-approved-budget field-display--above']})
    h=str(g).replace('<div>','</div>')
    approved_total=h.split('</div>')[2]
    # find status 
    gg=blupage_soup.find_all('div',{'class':['field--wrapp']})
    status=str(gg).split('</span>')[1].split('</div>')[0]
    table=pd.DataFrame([[name,i,description,date,country,status,approved_total]],columns=['name','url','description','date','country','status','approved_total'])
    big_table=pd.concat([big_table,table],axis=0)
    print('{}finished iteration '.format(name))
# Out:
# support-establishment-specialised-micro-and-small-business-financing-assessment-unit-withinfinished iteration
# essex-valley-irrigation-projectfinished iteration
# strengthening-food-safety-management-systemsfinished iteration
# energy-efficiency-measures-and-solar-photovoltaic-plantfinished iteration
# road-and-bridge-rehabilitation-loubiere-bagatelle-road-and-road-network-and-road-safety-assessmentfinished iteration
# road-infrastructure-rehabilitationfinished iteration
# education-quality-improvement-projectfinished iteration
# water-supply-expansion-and-sewerage-improvement-projectfinished iteration
# skills-development-and-employability-projectfinished iteration
# technical-assistance-geomatics-capacity-enhancement-disaster-risk-managementfinished iteration
# street-and-flood-light-retrofitting-projectfinished iteration
# power-project-electricity-system-upgrade-and-expansionfinished iteration
# second-road-infrastructure-rehabilitation-projectfinished iteration
# street-light-retrofitting-projectfinished iteration
# climate-smart-agriculture-and-rural-enterprise-programmefinished iteration
# rehabilitation-and-reconstruction-loan-hurricane-irmafinished iteration
# costal-and-river-infrastructure-rehabilitation-preparation-feasibility-study-and-detailed-designsfinished iteration
# rehabilitation-and-reconstruction-loan-hurricane-mariafinished iteration
# hurricane-recovery-support-loanfinished iteration
# port-modernisation-project-kingstown-st-vincent-and-grenadinesfinished iteration
# millennium-highway-and-west-coast-road-upgrading-projectfinished iteration
# montserrat-port-development-projectfinished iteration
# coastal-highway-upgrading-feasibility-study-and-preparation-detailed-designsfinished iteration
# education-sector-support-projectfinished iteration
# seventh-power-projectfinished iteration
# emergency-support-loan-liat-1974-limitedfinished iteration
# emergency-support-loan-liat-1974-limited-1finished iteration
# rehabilitation-and-reconstruction-hurricane-irmafinished iteration
# eighth-consolidated-line-creditfinished iteration
# belize-social-investment-fund-iiifinished iteration
# third-growth-and-resilience-building-policy-based-loanfinished iteration
# energy-sector-policy-based-loanfinished iteration
# power-project-suriname-electricity-system-upgrade-and-expansionfinished iteration
# support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2013-2014-hurricanefinished iteration
# education-all-project-phase-iifinished iteration
# support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2014-2015-hurricanefinished iteration
# technical-assistance-sanitation-and-governance-training-programmefinished iteration
# support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2015-2016-hurricanefinished iteration
# technical-and-vocational-education-and-training-project-ii-republic-haitifinished iteration
# community-based-agriculture-and-rural-developmentfinished iteration
# disaster-management-emergency-relief-grant-hurricane-matthewfinished iteration
# support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2017-2018-hurricanefinished iteration
# enhancement-technical-and-vocational-education-and-training-lower-secondary-school-level-surinamefinished iteration
# economic-stability-and-resilience-building-policy-based-loan-british-virgin-islandsfinished iteration
# youth-resilience-and-inclusive-social-empowerment-rise-projectfinished iteration
# immediate-response-hurricane-earlfinished iteration
# technical-and-vocational-education-and-training-development-revision-scope-additional-loanfinished iteration
# anguilla-bank-resolution-bridge-bank-capitalisationfinished iteration
# disaster-reduction-climate-change-adaptationfinished iteration
# third-water-supply-project-water-area-1-network-upgradefinished iteration
# preparation-comprehensive-sport-development-initiative-new-faculty-sport-university-west-indiesfinished iteration
# establishment-caribbean-regional-technical-assistance-centre-continuation-support-contribution-phasefinished iteration
# african-caribbean-pacific-european-union-caribbean-development-bank-natural-disaster-risk-managementfinished iteration
# building-individual-and-social-resilience-cope-impacts-natural-hazard-events-enhancing-capacityfinished iteration
# rehabilitation-and-reconstruction-loan-hurricane-maria-dominica-electricity-services-limitedfinished iteration
# support-haiti-meet-commitment-caribbean-catastrophe-risk-insurance-facility-2016-2017-hurricanefinished iteration
# building-capacity-disaster-risk-management-and-climate-resilience-project-ile-vachefinished iteration
# quality-enhancement-public-educationfinished iteration

# %%
big_table.index=range(len(big_table))

# %%
big_table
# Out:
#                                                  name  \
# 0   support-establishment-specialised-micro-and-sm...
# 1                     essex-valley-irrigation-project
# 2        strengthening-food-safety-management-systems
# 3   energy-efficiency-measures-and-solar-photovolt...
# 4   road-and-bridge-rehabilitation-loubiere-bagate...
# 5                  road-infrastructure-rehabilitation
# 6               education-quality-improvement-project
# 7   water-supply-expansion-and-sewerage-improvemen...
# 8        skills-development-and-employability-project
# 9   technical-assistance-geomatics-capacity-enhanc...
# 10        street-and-flood-light-retrofitting-project
# 11  power-project-electricity-system-upgrade-and-e...
# 12  second-road-infrastructure-rehabilitation-project
# 13                  street-light-retrofitting-project
# 14  climate-smart-agriculture-and-rural-enterprise...
# 15  rehabilitation-and-reconstruction-loan-hurrica...
# 16  costal-and-river-infrastructure-rehabilitation...
# 17  rehabilitation-and-reconstruction-loan-hurrica...
# 18                    hurricane-recovery-support-loan
# 19  port-modernisation-project-kingstown-st-vincen...
# 20  millennium-highway-and-west-coast-road-upgradi...
# 21                montserrat-port-development-project
# 22  coastal-highway-upgrading-feasibility-study-an...
# 23                   education-sector-support-project
# 24                              seventh-power-project
# 25           emergency-support-loan-liat-1974-limited
# 26         emergency-support-loan-liat-1974-limited-1
# 27   rehabilitation-and-reconstruction-hurricane-irma
# 28                    eighth-consolidated-line-credit
# 29                  belize-social-investment-fund-iii
# 30  third-growth-and-resilience-building-policy-ba...
# 31                    energy-sector-policy-based-loan
# 32  power-project-suriname-electricity-system-upgr...
# 33  support-haiti-meet-commitment-caribbean-catast...
# 34                     education-all-project-phase-ii
# 35  support-haiti-meet-commitment-caribbean-catast...
# 36  technical-assistance-sanitation-and-governance...
# 37  support-haiti-meet-commitment-caribbean-catast...
# 38  technical-and-vocational-education-and-trainin...
# 39  community-based-agriculture-and-rural-development
# 40  disaster-management-emergency-relief-grant-hur...
# 41  support-haiti-meet-commitment-caribbean-catast...
# 42  enhancement-technical-and-vocational-education...
# 43  economic-stability-and-resilience-building-pol...
# 44  youth-resilience-and-inclusive-social-empowerm...
# 45                  immediate-response-hurricane-earl
# 46  technical-and-vocational-education-and-trainin...
# 47  anguilla-bank-resolution-bridge-bank-capitalis...
# 48       disaster-reduction-climate-change-adaptation
# 49  third-water-supply-project-water-area-1-networ...
# 50  preparation-comprehensive-sport-development-in...
# 51  establishment-caribbean-regional-technical-ass...
# 52  african-caribbean-pacific-european-union-carib...
# 53  building-individual-and-social-resilience-cope...
# 54  rehabilitation-and-reconstruction-loan-hurrica...
# 55  support-haiti-meet-commitment-caribbean-catast...
# 56  building-capacity-disaster-risk-management-and...
# 57               quality-enhancement-public-education
#
#                                                   url  \
# 0   https://www.caribank.org/our-work/projects-map...
# 1   https://www.caribank.org/our-work/projects-map...
# 2   https://www.caribank.org/our-work/projects-map...
# 3   https://www.caribank.org/our-work/projects-map...
# 4   https://www.caribank.org/our-work/projects-map...
# 5   https://www.caribank.org/our-work/projects-map...
# 6   https://www.caribank.org/our-work/projects-map...
# 7   https://www.caribank.org/our-work/projects-map...
# 8   https://www.caribank.org/our-work/projects-map...
# 9   https://www.caribank.org/our-work/projects-map...
# 10  https://www.caribank.org/our-work/projects-map...
# 11  https://www.caribank.org/our-work/projects-map...
# 12  https://www.caribank.org/our-work/projects-map...
# 13  https://www.caribank.org/our-work/projects-map...
# 14  https://www.caribank.org/our-work/projects-map...
# 15  https://www.caribank.org/our-work/projects-map...
# 16  https://www.caribank.org/our-work/projects-map...
# 17  https://www.caribank.org/our-work/projects-map...
# 18  https://www.caribank.org/our-work/projects-map...
# 19  https://www.caribank.org/our-work/projects-map...
# 20  https://www.caribank.org/our-work/projects-map...
# 21  https://www.caribank.org/our-work/projects-map...
# 22  https://www.caribank.org/our-work/projects-map...
# 23  https://www.caribank.org/our-work/projects-map...
# 24  https://www.caribank.org/our-work/projects-map...
# 25  https://www.caribank.org/our-work/projects-map...
# 26  https://www.caribank.org/our-work/projects-map...
# 27  https://www.caribank.org/our-work/projects-map...
# 28  https://www.caribank.org/our-work/projects-map...
# 29  https://www.caribank.org/our-work/projects-map...
# 30  https://www.caribank.org/our-work/projects-map...
# 31  https://www.caribank.org/our-work/projects-map...
# 32  https://www.caribank.org/our-work/projects-map...
# 33  https://www.caribank.org/our-work/projects-map...
# 34  https://www.caribank.org/our-work/projects-map...
# 35  https://www.caribank.org/our-work/projects-map...
# 36  https://www.caribank.org/our-work/projects-map...
# 37  https://www.caribank.org/our-work/projects-map...
# 38  https://www.caribank.org/our-work/projects-map...
# 39  https://www.caribank.org/our-work/projects-map...
# 40  https://www.caribank.org/our-work/projects-map...
# 41  https://www.caribank.org/our-work/projects-map...
# 42  https://www.caribank.org/our-work/projects-map...
# 43  https://www.caribank.org/our-work/projects-map...
# 44  https://www.caribank.org/our-work/projects-map...
# 45  https://www.caribank.org/our-work/projects-map...
# 46  https://www.caribank.org/our-work/projects-map...
# 47  https://www.caribank.org/our-work/projects-map...
# 48  https://www.caribank.org/our-work/projects-map...
# 49  https://www.caribank.org/our-work/projects-map...
# 50  https://www.caribank.org/our-work/projects-map...
# 51  https://www.caribank.org/our-work/projects-map...
# 52  https://www.caribank.org/our-work/projects-map...
# 53  https://www.caribank.org/our-work/projects-map...
# 54  https://www.caribank.org/our-work/projects-map...
# 55  https://www.caribank.org/our-work/projects-map...
# 56  https://www.caribank.org/our-work/projects-map...
# 57  https://www.caribank.org/our-work/projects-map...
#
#                                           description            date  \
# 0   This Project is expected to contribute to incr...       May, 2016
# 1   The project aims to enhance production and pro...     March, 2018
# 2   The project aims to enhance the compliance of ...      July, 2017
# 3   The project aims to reduce the consumption of ...       May, 2017
# 4    The technical assistance aims to provide the ...       May, 2016
# 5   The project is expected to contribute to incre...  December, 2016
# 6   The overall objective of the project is improv...  December, 2016
# 7   The aim of the project is to provide the Natio...  December, 2016
# 8   The overall outcome of the project is to assis...  December, 2016
# 9   The project is designed to enhance the capacit...  December, 2016
# 10  The project aims to reduce street and flood li...  December, 2016
# 11  The Project aims to deliver quality power supp...  December, 2017
# 12  The expected outcome of the project is a road ...     March, 2017
# 13  The expected outcomes of the project are reduc...      July, 2016
# 14  The project is designed to enhance the capacit...  December, 2017
# 15  The expected outcomes of the project are a ful...  December, 2017
# 16  The expected outcome of this intervention is t...       May, 2017
# 17   The project aims to fully restore the electri...     March, 2018
# 18   The project will assist the Government of Ang...       May, 2018
# 19  The objective of this project is to conduct st...   October, 2017
# 20  This intervention aims to enhance capacity of ...  December, 2017
# 21  The project aims to improve the efficiency, ef...  December, 2017
# 22  The outcome of this intervention is to establi...       May, 2017
# 23  The project aims to improve the quality, equit...      July, 2017
# 24  The project aims to improve the capacity, and ...      July, 2017
# 25   This project will assist in financing emergen...  December, 2017
# 26   This project will assist in financing emergen...  December, 2017
# 27  The expected outcomes of the Project are resto...  December, 2017
# 28  This project aims to satisfy unmet credit need...  December, 2016
# 29  The project aims to increase gender-equitable ...  December, 2016
# 30   The policy-based loan supports the implementa...  December, 2016
# 31  The development objective of the Policy-Based ...       May, 2016
# 32  The Project aims to deliver quality power supp...  December, 2017
# 33  The grant to Haiti covers the country’s 2013-2...      July, 2013
# 34  The outcome of the Project is improved access ...      July, 2013
# 35  \n<style type="text/css">\n<!--/*--><![CDATA[/...      July, 2015
# 36  The Project will support the financing of a Go...      July, 2015
# 37  The grant to Haiti covers the country’s 2015-2...      July, 2015
# 38  The objective of the Project is to provide inc...  December, 2015
# 39  The objective of the Project is to improve acc...     March, 2016
# 40  The objective of the Grant is to provide resou...   October, 2016
# 41  The grant to Haiti covers the country’s 2017-2...       May, 2017
# 42  The objective of the Project is improved learn...  December, 2014
# 43  The Policy-Based Loan is structured around two...     March, 2018
# 44  The project aims to improve the resilience of ...     March, 2016
# 45   The project will assist the Government of Bel...     March, 2016
# 46   The expected outcome of the project is a high...     March, 2016
# 47  The project objective is to improve stability ...       May, 2016
# 48  This project aims to reduce the vulnerability ...     March, 2016
# 49  The expected outcome of the revised Project is...   October, 2016
# 50  The overall objective of this technical assist...       May, 2018
# 51  The objective of this technical assistance is ...     March, 2018
# 52  The expected outcome of the Project is the dev...     March, 2018
# 53  The expected overall outcome of the project is...     March, 2018
# 54  The expected outcomes of the Project are: a fu...     March, 2018
# 55  The grant to Haiti covers the country’s 2016-2...       May, 2016
# 56                               The Project aims to:       May, 2017
# 57  After a Canada/Commonwealth Caribbean Conferen...  December, 2017
#
#                              country  status  \
# 0                              Haiti  Active
# 1                            Jamaica      \n
# 2                            Grenada  Active
# 3   Saint Vincent and the Grenadines      \n
# 4                           Dominica      \n
# 5                Antigua and Barbuda      \n
# 6                        Saint Lucia  Active
# 7                            Grenada      \n
# 8                             Guyana  Active
# 9                        The Bahamas  Active
# 10             Saint Kitts and Nevis      \n
# 11                          Suriname  Active
# 12               Antigua and Barbuda  Active
# 13               Antigua and Barbuda      \n
# 14                           Grenada      \n
# 15                          Anguilla      \n
# 16                            Guyana      \n
# 17                          Dominica      \n
# 18                          Anguilla  Active
# 19  Saint Vincent and the Grenadines      \n
# 20                       Saint Lucia      \n
# 21                        Montserrat      \n
# 22                            Belize      \n
# 23            British Virgin Islands  Active
# 24                          Anguilla  Active
# 25               Antigua and Barbuda  Active
# 26                          Barbados  Active
# 27               Antigua and Barbuda      \n
# 28                            Belize  Active
# 29                            Belize      \n
# 30                           Grenada  Active
# 31                          Suriname      \n
# 32                          Suriname  Active
# 33                             Haiti  Active
# 34                             Haiti      \n
# 35                             Haiti  Active
# 36                             Haiti  Active
# 37                             Haiti  Active
# 38                             Haiti  Active
# 39                             Haiti  Active
# 40                             Haiti  Active
# 41                             Haiti  Active
# 42                          Suriname  Active
# 43            British Virgin Islands  Active
# 44                            Belize  Active
# 45                            Belize  Active
# 46  Saint Vincent and the Grenadines  Active
# 47                          Anguilla  Active
# 48  Saint Vincent and the Grenadines  Active
# 49                          Dominica  Active
# 50                          Regional  Active
# 51                          Regional  Active
# 52                          Regional  Active
# 53                          Dominica  Active
# 54                          Dominica  Active
# 55                             Haiti  Active
# 56                             Haiti      \n
# 57                             Haiti  Active
#
#                         approved_total
# 0                             $500,000
# 1                         £ 35,515,000
# 2    $850,000 (loan), $250,000 (grant)
# 3                           $4,196,000
# 4                            £ 794,446
# 5                         £ 13,900,000
# 6                         $ 23,410,000
# 7                            £ 707,070
# 8                         $ 11,700,000
# 9                          $ 2,893,000
# 10                         $ 5,792,000
# 11                        $ 65,000,000
# 12                         $45,859,000
# 13                          $5,981,000
# 14                          $5,000,000
# 15                          $5,313,000
# 16                         £ 1,433,000
# 17                        $ 15,804,000
# 18                         $ 5,600,000
# 19                      £ 2,424,000.00
# 20                        £ 979,605.00
# 21                        £ 14,400,000
# 22                         £ 1,000,000
# 23                         $ 9,298,700
# 24                         $ 6,230,000
# 25                         $ 2,440,000
# 26                         $ 3,720,000
# 27                         $28,761,000
# 28                         $20,000,000
# 29                         $10,000,000
# 30                        $ 10,000,000
# 31                         $50,000,000
# 32                         $65,000,000
# 33                          $2,570,000
# 34                         $11,000,000
# 35                          $2,377,250
# 36                            $211,000
# 37                          $2,377,250
# 38                         $12,510,000
# 39                          $8,000,000
# 40                            $200,000
# 41                          $3,500,000
# 42                         $21,940,000
# 43                         $50,000,000
# 44  $ 984,000 (loan), $750,000 (grant)
# 45                           $ 750,000
# 46                         $ 7,317,000
# 47                        $ 22,000,000
# 48                         $11,200,000
# 49                         $10,538,200
# 50                            $210,000
# 51                         $1,029,207
# 52                          $1,063,395
# 53                            $467,800
# 54                         $16,015,000
# 55                          $3,500,000
# 56                          $5,500,000
# 57                         $16,000,000
